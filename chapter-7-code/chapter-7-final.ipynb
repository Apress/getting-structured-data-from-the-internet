# %%
# Listing 7-1: creating a new database in Athena

import boto3
import numpy as np
import pandas as pd

def run_query(query, database, s3_output):
    client = boto3.client('athena', region_name='us-east-1')
    response = client.start_query_execution(
        QueryString=query,
        QueryExecutionContext={
            'Database': database
            },
        ResultConfiguration={
            'OutputLocation': s3_output,
            }
        )
    print('Execution ID: ' + response['QueryExecutionId'])
    return response['QueryExecutionId']

# %%
# Listing 7-1: creating a new database in Athena (cont.)

query = '''Create database domainranks2'''

database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 5f030e8e-7fd7-4487-b388-ef61cb6b7502

# %%
# Listing 7-2: creating a new table
query = '''CREATE EXTERNAL TABLE IF NOT EXISTS domainranks2.domain_ranks (
`#harmonicc_pos` bigint,
`#harmonicc_val` double,
`#pr_pos` bigint,
`#pr_val` double,
`#host_rev` string,
`#n_hosts` int)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
WITH SERDEPROPERTIES (
 'serialization.format' = '	',
 'field.delim' = '	',
 'collection.delim' = '#',
 'mapkey.delim' = '#'
) LOCATION 's3://athena-us-east-1-testing/domain_ranks/'
TBLPROPERTIES ('has_encrypted_data'='false')'''


database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 5d41677a-3592-42e6-b250-c995987e5770

# %%
# Listing 7-3: querying for ranks for theguardian.com
query = '''SELECT * FROM domainranks2.domain_ranks where domain_ranks."#host_rev" = 'com.theguardian';'''
database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: caa1997d-3625-4598-920b-6f3058ecc742

# %%
# Listing 7-4: Fetching query results from Athena

def get_raw_response(execution_id):
    
    client = boto3.client('athena', region_name='us-east-1')
    response = client.get_query_results(
        QueryExecutionId=execution_id,
        MaxResults=123
    )
    return response

def results_to_df(results):

    columns = [
        col['Label'] for col in results['ResultSet']['ResultSetMetadata']['ColumnInfo']]

    listed_results = []
    for res in results['ResultSet']['Rows'][1:]:
        values = []
        for field in res['Data']:
            try:
                values.append(list(field.values())[0]) 
            except:
                values.append(list(' '))

        listed_results.append(
            dict(zip(columns, values))
        )

    return listed_results

# %%
# Listing 7-4: Fetching query results from Athena


import time
for i in range(15):
    time.sleep(10)

    try:
        return_json = get_raw_response(execution_id)
        t = results_to_df(return_json)
        df_2 = pd.DataFrame(t)
        print("query successful")
        break
    except Exception as e:

        print(e)
        
        pass
# Out:
# query successful

# %%
# Listing 7-4: Fetching query results from Athena


df_2.head()
# Out:
#   #harmonicc_pos #harmonicc_val        #host_rev #n_hosts #pr_pos  \
# 0             92     2.043555E7  com.theguardian      127     171
#
#                  #pr_val
# 0  1.4701598631846095E-4

# %%
# Listing 7-5: Creating additional table with just inverted urls

df = pd.read_csv("inverted_urls_list.csv")
df.head()
# Out:
#             urls  inverted_urls
# 0   facebook.com   com.facebook
# 1     google.com     com.google
# 2    youtube.com    com.youtube
# 3    twitter.com    com.twitter
# 4  instagram.com  com.instagram

# %%
# Listing 7-6: Creating additional table inverted urls

query = '''CREATE EXTERNAL TABLE IF NOT EXISTS urltest (
 `urls` STRING,
 `inverted_urls` STRING)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde' 
WITH SERDEPROPERTIES ( 
  'escapeChar'='\\\\', 
  'separatorChar'=','
  ) LOCATION 's3://athena-us-east-1-testing/sample-folder/' 
TBLPROPERTIES ('has_encrypted_data'='false', 'skip.header.line.count' = '1');'''

database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# https://stackoverflow.com/questions/40912086/amazon-athena-no-viable-alternative-at-input
# Out:
# Execution ID: 354f96ce-8f10-4dcf-b8d7-fc5e8d0a94ff

# %%
# Listing 7-7: Testing new Athena table

query = '''select * from domainranks2.urltest'''
database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 6225c27f-a8e6-4468-83c5-5dbe5a56139a

# %%
# Listing 7-7: Testing new Athena table


return_json = get_raw_response(execution_id)
t = results_to_df(return_json)
df_2 = pd.DataFrame(t)
df_2.head()
# Out:
#    inverted_urls           urls
# 0   com.facebook   facebook.com
# 1     com.google     google.com
# 2    com.youtube    youtube.com
# 3    com.twitter    twitter.com
# 4  com.instagram  instagram.com

# %%
# Listing 7-8: fetching harmonic centrality and pagerank rankings

query = '''select urltest."inverted_urls",urltest."urls", domain_ranks."#harmonicc_pos", domain_ranks."#harmonicc_val", domain_ranks."#n_hosts", domain_ranks."#pr_pos", domain_ranks."#pr_val"
FROM urltest, domain_ranks
WHERE domain_ranks."#host_rev" = urltest."inverted_urls"'''
database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 675d2d2e-3597-4df8-a0b1-b2fee64748c1

# %%
# Listing 7-8: fetching harmonic centrality and pagerank rankings


import time
for i in range(15):
    time.sleep(10)

    try:
        return_json = get_raw_response(execution_id)
        t = results_to_df(return_json)
        df_2 = pd.DataFrame(t)
        print("query successful")
        break
    except Exception as e:

        print(e)
        
        pass
# Out:
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# An error occurred (InvalidRequestException) when calling the GetQueryResults operation: Query has not yet finished. Current state: RUNNING
# query successful

# %%
# Listing 7-8: fetching harmonic centrality and pagerank rankings


df_2.head()
# Out:
#   #harmonicc_pos #harmonicc_val #n_hosts #pr_pos                #pr_val  \
# 0             24     2.153328E7      100      31  0.0011040749131266557
# 1             80    2.0488868E7     5116     373    6.71641116389417E-5
# 2             67    2.0609614E7      464     154   1.692129080835582E-4
# 3         236490    1.6137525E7       17     116    2.57561600845181E-4
# 4            146    2.0222314E7      123     339   7.442682626049672E-5
#
#   inverted_urls        urls
# 0     com.vimeo   vimeo.com
# 1       com.msn     msn.com
# 2      com.bing    bing.com
# 3    com.cpanel  cpanel.com
# 4      com.time    time.com

# %%
# Listing 7-9: Setting up CC index Athena table

query = '''CREATE EXTERNAL TABLE IF NOT EXISTS ccindex (
  `url_surtkey`                   STRING,
  `url`                           STRING,
  `url_host_name`                 STRING,
  `url_host_tld`                  STRING,
  `url_host_2nd_last_part`        STRING,
  `url_host_3rd_last_part`        STRING,
  `url_host_4th_last_part`        STRING,
  `url_host_5th_last_part`        STRING,
  `url_host_registry_suffix`      STRING,
  `url_host_registered_domain`    STRING,
  `url_host_private_suffix`       STRING,
  `url_host_private_domain`       STRING,
  `url_protocol`                  STRING,
  `url_port`                      INT,
  `url_path`                      STRING,
  `url_query`                     STRING,
  `fetch_time`                    TIMESTAMP,
  `fetch_status`                  SMALLINT,
  `fetch_redirect`                STRING,
  `content_digest`                STRING,
  `content_mime_type`             STRING,
  `content_mime_detected`         STRING,
  `content_charset`               STRING,
  `content_languages`             STRING,
  `content_truncated`             STRING,
  `warc_filename`                 STRING,
  `warc_record_offset`            INT,
  `warc_record_length`            INT,
  `warc_segment`                  STRING)
PARTITIONED BY (
  `crawl`                         STRING,
  `subset`                        STRING)
STORED AS parquet
LOCATION 's3://commoncrawl/cc-index/table/cc-main/warc/';'''

database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 624e854f-26fb-4209-b474-c101a829e5e8

# %%
# Listing 7-10: table repair query

query = '''MSCK REPAIR TABLE ccindex;'''

database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 3e93d268-7b8e-4eab-a6f8-1fe9503684ca

# %%
# Listing 7-11: sample query on cc-index

query = '''SELECT url_surtkey, url, warc_filename, warc_record_offset, warc_record_length,
content_mime_detected, fetch_status, content_languages
FROM domainranks2.ccindex
WHERE crawl = 'CC-MAIN-2020-24'
AND url LIKE 'http%://www.cnn.com/'
AND subset = 'warc'
AND url_host_registered_domain = 'cnn.com'
LIMIT 5;'''

database = 'domainranks2'
s3_output = 's3://athena-us-east-1-testing/query-folder2/'
execution_id = run_query(query, database, s3_output)
# Out:
# Execution ID: 22d233a9-a2e5-4543-83da-81314dd9d256

# %%
# Listing 7-11: sample query on cc-index


import time
for i in range(15):
    time.sleep(10)

    try:
        return_json = get_raw_response(execution_id)
        t = results_to_df(return_json)
        df_2 = pd.DataFrame(t)
        print("query successful")
        break
    except Exception as e:

        print(e)
        
        pass
df_2.head()
# Out:
# query successful
#   content_languages content_mime_detected fetch_status                   url  \
# 0               eng             text/html          200  https://www.cnn.com/
# 1               eng             text/html          200  https://www.cnn.com/
# 2               eng             text/html          200  https://www.cnn.com/
# 3               eng             text/html          200  https://www.cnn.com/
# 4               eng             text/html          200  https://www.cnn.com/
#
#   url_surtkey                                      warc_filename  \
# 0   com,cnn)/  crawl-data/CC-MAIN-2020-24/segments/1590347387...
# 1   com,cnn)/  crawl-data/CC-MAIN-2020-24/segments/1590347387...
# 2   com,cnn)/  crawl-data/CC-MAIN-2020-24/segments/1590347388...
# 3   com,cnn)/  crawl-data/CC-MAIN-2020-24/segments/1590347388...
# 4   com,cnn)/  crawl-data/CC-MAIN-2020-24/segments/1590347389...
#
#   warc_record_length warc_record_offset
# 0             143892          693352534
# 1             144002          676690049
# 2             144422          697305859
# 3             144466          647676538
# 4             144118          680989734

# %%
# extruct page demo (not shown in text)
import requests
import pprint

url = 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'
my_headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 ' + ' (KHTML, like Gecko) Chrome/61.0.3163.100Safari/537.36'
}


r = requests.get(url, headers = my_headers)


html_response = r.text

import extruct
data = extruct.extract(r.text)
data_keys = data.keys()
for key in data_keys:
    print("*"*10)
    print(key)
    pprint.pprint(data[key])
# Out:
# **********
# microdata
# [{'type': 'http://schema.org/WebPage',
#   'value': 'Skip to main content\n'
#            'The Guardian - Back to home\n'
#            'Support The Guardian\n'
#            'Available for everyone, funded by readers\n'
#            'Contribute Subscribe Contribute\n'
#            'Search jobs\n'
#            'Sign in My account\n'
#            '\n'
#            'Account overview\n'
#            'Profile\n'
#            'Emails & marketing\n'
#            'Settings\n'
#            'Help\n'
#            'Comments & replies\n'
#            'Sign out\n'
#            '\n'
#            'Search\n'
#            '\n'
#            'switch to the International edition\n'
#            'switch to the UK edition\n'
#            'switch to the US edition\n'
#            'switch to the Australia edition\n'
#            '\n'
#            'current edition: International edition\n'
#            '\n'
#            'News\n'
#            'Opinion\n'
#            'Sport\n'
#            'Culture\n'
#            'Lifestyle\n'
#            '\n'
#            'Show More\n'
#            '\n'
#            'News\n'
#            '\n'
#            'Coronavirus\n'
#            'World news\n'
#            'UK news\n'
#            'Environment\n'
#            'Science\n'
#            'Global development\n'
#            'Football\n'
#            'Tech\n'
#            'Business\n'
#            'Obituaries\n'
#            '\n'
#            'Opinion\n'
#            '\n'
#            'The Guardian view\n'
#            'Columnists\n'
#            'Cartoons\n'
#            'Opinion videos\n'
#            'Letters\n'
#            '\n'
#            'Sport\n'
#            '\n'
#            'Football\n'
#            'Cricket\n'
#            'Rugby union\n'
#            'Tennis\n'
#            'Cycling\n'
#            'F1\n'
#            'Golf\n'
#            'US sports\n'
#            '\n'
#            'Culture\n'
#            '\n'
#            'Books\n'
#            'Music\n'
#            'TV & radio\n'
#            'Art & design\n'
#            'Film\n'
#            'Games\n'
#            'Classical\n'
#            'Stage\n'
#            '\n'
#            'Lifestyle\n'
#            '\n'
#            'Fashion\n'
#            'Food\n'
#            'Recipes\n'
#            'Love & sex\n'
#            'Health & fitness\n'
#            'Home & garden\n'
#            'Women\n'
#            'Men\n'
#            'Family\n'
#            'Travel\n'
#            'Money\n'
#            '\n'
#            'What term do you want to search? Search with google\n'
#            '\n'
#            'Make a contribution\n'
#            'Subscribe\n'
#            '\n'
#            'International edition\n'
#            '\n'
#            'switch to the UK edition\n'
#            'switch to the US edition\n'
#            'switch to the Australia edition\n'
#            '\n'
#            'Search jobs\n'
#            'Holidays\n'
#            'Digital Archive\n'
#            'Discount Codes\n'
#            'Guardian Puzzles app\n'
#            'The Guardian app\n'
#            'Video\n'
#            'Podcasts\n'
#            'Pictures\n'
#            'Newsletters\n'
#            "Today's paper\n"
#            'Inside the Guardian\n'
#            'The Observer\n'
#            'Guardian Weekly\n'
#            'Crosswords\n'
#            'Facebook\n'
#            'Twitter\n'
#            '\n'
#            'Search jobs\n'
#            'Holidays\n'
#            'Digital Archive\n'
#            'Discount Codes\n'
#            'Guardian Puzzles app\n'
#            '\n'
#            'Business\n'
#            'Economics\n'
#            'Banking\n'
#            'Money\n'
#            'Markets\n'
#            'Project Syndicate\n'
#            'B2B\n'
#            'Retail\n'
#            '\n'
#            'More\n'
#            'Waitrose\n'
#            'This article is more than 6 months old\n'
#            '\n'
#            'Waitrose to launch charm offensive as Ocado switches to M&S\n'
#            '\n'
#            'This article is more than 6 months old\n'
#            '\n'
#            'Supermarket will launch thousands of new and revamped products '
#            'aiming to retain online customers\n'
#            '\n'
#            'Zoe Wood\n'
#            '\n'
#            '@zoewoodguardian\n'
#            '\n'
#            'Mon 10 Feb 2020 06.00 GMT Last modified on Wed 12 Feb 2020 13.42 '
#            'GMT\n'
#            '\n'
#            'Share on Facebook\n'
#            'Share on Twitter\n'
#            'Share via Email\n'
#            '\n'
#            'Analysts suggest the end of the Ocado deal may have badly affect '
#            'Waitrose’s owner, the John Lewis Partnership. Photograph: Andrew '
#            'Matthews/PA\n'
#            '\n'
#            'Waitrose is to launch thousands of new and revamped products in '
#            'the coming months as the battle for the hearts and minds of Ocado '
#            'shoppers moves up a gear.\n'
#            '\n'
#            'The supermarket’s deal with the online grocer will finish at the '
#            'end of August, when it will be replaced by Marks & Spencer. The '
#            'switchover is high risk for all the brands involved: Ocado risks '
#            'losing loyal Waitrose shoppers while the supermarket, which is '
#            'part of the John Lewis Partnership, will have to persuade shoppers '
#            'to use its own website instead.\n'
#            '\n'
#            'Last year, Ocado fired the opening salvo stating its product range '
#            'would be bigger, cheaper and better quality under the M&S deal. '
#            'The online grocer will stock 6,000 M&S products, compared with the '
#            '4,000 it sells as part of its supply deal with Waitrose. The '
#            'alternatives would be the “same price or lower, and of the same '
#            'quality or better” than the Waitrose ones, Ocado said.\n'
#            '\n'
#            'Waitrose on the other hand says it is working on 5,000 new or '
#            'reformulated products – a figure that equates to nearly a third of '
#            'the 17,000 own-label products sold under house brands such as '
#            'Duchy, Essential Waitrose and No.1. To come up with more '
#            'distinctive products the retailer has made a multimillion-pound '
#            'investment in the kitchens at its Bracknell headquarters in '
#            'Berkshire.\n'
#            '\n'
#            'Sign up to the daily Business Today email or follow Guardian '
#            'Business on Twitter at @BusinessDesk\n'
#            '\n'
#            'The supermarket is also running a “you can taste when it’s '
#            'Waitrose” advertising campaign to underline its foodie '
#            'credentials. With short ads focused on “hand-rolled white '
#            'sourdough bread made in London” and “100% Italian” olive oil '
#            'produced in Umbria, the marketing push aims to claim the high '
#            'ground as the UK’s “leading quality food retailer” selling '
#            'products “unrivalled on quality and taste”.\n'
#            '\n'
#            'The charm offensive comes ahead of Ocado’s full-year results on '
#            'Tuesday when an update on the M&S joint venture is anticipated. '
#            'After nearly a decade as an unloved listed company, Ocado has '
#            'become a stock market darling after its chief executive, Tim '
#            'Steiner, sold its grocery-picking expertise to several foreign '
#            'supermarkets.\n'
#            '\n'
#            'Ocado’s shares have risen 40% over the past 12 months with the '
#            'company worth more than £8bn, primarily thanks to the overseas '
#            'deals banked by its tech arm Ocado Solutions (M&S paid £750m for '
#            '50% of Ocado Retail, the subsidiary that operates robotic '
#            'warehouses in the UK). The year was not without its setbacks: its '
#            'hi-tech warehouse in Andover, Hampshire, was destroyed in a fire. '
#            'Analysts at Bernstein expect pre-tax losses to have widened to '
#            '£204m on sales of £1.8bn in 2019.\n'
#            '\n'
#            'In praise of delivery drivers – those unsung, everyday heroes\n'
#            '\n'
#            'Read more\n'
#            '\n'
#            'Waitrose had enlisted Today Development Partners, a technology '
#            'business run by Ocado co-founder Jonathan Faiman, to help grow its '
#            'online operation without Ocado. However, the deal ended after just '
#            'four months and it subsequently emerged Faiman, who left the '
#            'online business in 2009, was being sued by Ocado.\n'
#            '\n'
#            'Thomas Davies, a retail analyst at Berenberg bank, expects some '
#            'Waitrose shoppers to defect but suggests they will be replaced by '
#            'M&S customers who can’t buy its food online at the moment. Ocado '
#            'owns the customer data so “will be able to target those customers '
#            'that it views to be most at risk from switching”, he suggested.\n'
#            '\n'
#            '“While everyone is looking at the potential impact from Ocado’s '
#            'perspective, we believe investors are failing to acknowledge the '
#            'negative impact on Waitrose, from ending the Ocado contract,” '
#            'continued Davies who said the tie-up generated 6% of Waitrose’s '
#            'sales. “This will have a material impact on Waitrose’s owner, the '
#            'John Lewis Partnership, which is already struggling with margins '
#            'that have fallen.”\n'
#            '\n'
#            'Topics\n'
#            '\n'
#            'Waitrose\n'
#            '\n'
#            'Ocado\n'
#            'Retail industry\n'
#            'Online shopping\n'
#            'Marks & Spencer\n'
#            'John Lewis\n'
#            'Supermarkets\n'
#            'news\n'
#            '\n'
#            'Share on Facebook\n'
#            'Share on Twitter\n'
#            'Share via Email\n'
#            'Share on LinkedIn\n'
#            'Share on Pinterest\n'
#            'Share on WhatsApp\n'
#            'Share on Messenger\n'
#            '\n'
#            'Reuse this content\n'
#            '\n'
#            'more on this story\n'
#            '\n'
#            'John Lewis may turn surplus stores into affordable homes\n'
#            '\n'
#            'Partnership also plans to close some supermarkets and sell '
#            'own-label food at other retailers\n'
#            'Published: 30 Jul 2020\n'
#            'John Lewis may turn surplus stores into affordable homes\n'
#            '\n'
#            'Supermarkets bring in new measures to keep shoppers and staff '
#            'safe\n'
#            '\n'
#            'Stores will limit customer numbers and manage queues under latest '
#            'coronavirus rules\n'
#            'Published: 24 Mar 2020\n'
#            'Supermarkets bring in new measures to keep shoppers and staff '
#            'safe\n'
#            '\n'
#            'John Lewis staff bonus at 67-year low as more closures announced\n'
#            '\n'
#            'Three Waitrose stores to shut this year, putting about 400 jobs at '
#            'risk\n'
#            'Published: 5 Mar 2020\n'
#            'John Lewis staff bonus at 67-year low as more closures announced\n'
#            '\n'
#            'Waitrose boss Rob Collins steps down in £100m John Lewis cuts\n'
#            '\n'
#            'Supermarket’s parent group says 75 out of 225 head office '
#            'management posts will be axed\n'
#            'Published: 1 Oct 2019\n'
#            'Waitrose boss Rob Collins steps down in £100m John Lewis cuts\n'
#            '\n'
#            "'They sell duck eggs!' Waitrose shoppers react to closures\n"
#            '\n'
#            'Published: 20 Jul 2019\n'
#            "'They sell duck eggs!' Waitrose shoppers react to closures\n"
#            '\n'
#            'Waitrose to axe seven more stores putting 700 jobs at risk\n'
#            '\n'
#            'Published: 18 Jul 2019\n'
#            'Waitrose to axe seven more stores putting 700 jobs at risk\n'
#            '\n'
#            'Most popular\n'
#            '\n'
#            'Business\n'
#            'Economics\n'
#            'Banking\n'
#            'Money\n'
#            'Markets\n'
#            'Project Syndicate\n'
#            'B2B\n'
#            'Retail\n'
#            '\n'
#            'News\n'
#            'Opinion\n'
#            'Sport\n'
#            'Culture\n'
#            'Lifestyle\n'
#            '\n'
#            'Contact us\n'
#            'Complaints & corrections\n'
#            'SecureDrop\n'
#            'Work for us\n'
#            'Privacy policy\n'
#            'Cookie policy\n'
#            'Terms & conditions\n'
#            'Help\n'
#            '\n'
#            'All topics\n'
#            'All writers\n'
#            'Digital newspaper archive\n'
#            'Facebook\n'
#            'Twitter\n'
#            '\n'
#            'Advertise with us\n'
#            'Search UK jobs\n'
#            'Discount Codes\n'
#            '\n'
#            'Support The Guardian\n'
#            'Available for everyone, funded by readers\n'
#            'Contribute Subscribe\n'
#            'Back to top\n'
#            '© 2020 Guardian News & Media Limited or its affiliated companies. '
#            'All rights reserved.\n'
#            'Close'},
#  {'properties': {'articleBody': 'Waitrose is to launch thousands of new and '
#                                 'revamped products in the coming months as the '
#                                 'battle for the hearts and minds of Ocado '
#                                 'shoppers moves up a gear.\n'
#                                 '\n'
#                                 'The supermarket’s deal with the online grocer '
#                                 'will finish at the end of August, when it '
#                                 'will be replaced by Marks & Spencer. The '
#                                 'switchover is high risk for all the brands '
#                                 'involved: Ocado risks losing loyal Waitrose '
#                                 'shoppers while the supermarket, which is part '
#                                 'of the John Lewis Partnership, will have to '
#                                 'persuade shoppers to use its own website '
#                                 'instead.\n'
#                                 '\n'
#                                 'Last year, Ocado fired the opening salvo '
#                                 'stating its product range would be bigger, '
#                                 'cheaper and better quality under the M&S '
#                                 'deal. The online grocer will stock 6,000 M&S '
#                                 'products, compared with the 4,000 it sells as '
#                                 'part of its supply deal with Waitrose. The '
#                                 'alternatives would be the “same price or '
#                                 'lower, and of the same quality or better” '
#                                 'than the Waitrose ones, Ocado said.\n'
#                                 '\n'
#                                 'Waitrose on the other hand says it is working '
#                                 'on 5,000 new or reformulated products – a '
#                                 'figure that equates to nearly a third of the '
#                                 '17,000 own-label products sold under house '
#                                 'brands such as Duchy, Essential Waitrose and '
#                                 'No.1. To come up with more distinctive '
#                                 'products the retailer has made a '
#                                 'multimillion-pound investment in the kitchens '
#                                 'at its Bracknell headquarters in Berkshire.\n'
#                                 '\n'
#                                 'Sign up to the daily Business Today email or '
#                                 'follow Guardian Business on Twitter at '
#                                 '@BusinessDesk\n'
#                                 '\n'
#                                 'The supermarket is also running a “you can '
#                                 'taste when it’s Waitrose” advertising '
#                                 'campaign to underline its foodie credentials. '
#                                 'With short ads focused on “hand-rolled white '
#                                 'sourdough bread made in London” and “100% '
#                                 'Italian” olive oil produced in Umbria, the '
#                                 'marketing push aims to claim the high ground '
#                                 'as the UK’s “leading quality food retailer” '
#                                 'selling products “unrivalled on quality and '
#                                 'taste”.\n'
#                                 '\n'
#                                 'The charm offensive comes ahead of Ocado’s '
#                                 'full-year results on Tuesday when an update '
#                                 'on the M&S joint venture is anticipated. '
#                                 'After nearly a decade as an unloved listed '
#                                 'company, Ocado has become a stock market '
#                                 'darling after its chief executive, Tim '
#                                 'Steiner, sold its grocery-picking expertise '
#                                 'to several foreign supermarkets.\n'
#                                 '\n'
#                                 'Ocado’s shares have risen 40% over the past '
#                                 '12 months with the company worth more than '
#                                 '£8bn, primarily thanks to the overseas deals '
#                                 'banked by its tech arm Ocado Solutions (M&S '
#                                 'paid £750m for 50% of Ocado Retail, the '
#                                 'subsidiary that operates robotic warehouses '
#                                 'in the UK). The year was not without its '
#                                 'setbacks: its hi-tech warehouse in Andover, '
#                                 'Hampshire, was destroyed in a fire. Analysts '
#                                 'at Bernstein expect pre-tax losses to have '
#                                 'widened to £204m on sales of £1.8bn in 2019.\n'
#                                 '\n'
#                                 'In praise of delivery drivers – those unsung, '
#                                 'everyday heroes\n'
#                                 '\n'
#                                 'Read more\n'
#                                 '\n'
#                                 'Waitrose had enlisted Today Development '
#                                 'Partners, a technology business run by Ocado '
#                                 'co-founder Jonathan Faiman, to help grow its '
#                                 'online operation without Ocado. However, the '
#                                 'deal ended after just four months and it '
#                                 'subsequently emerged Faiman, who left the '
#                                 'online business in 2009, was being sued by '
#                                 'Ocado.\n'
#                                 '\n'
#                                 'Thomas Davies, a retail analyst at Berenberg '
#                                 'bank, expects some Waitrose shoppers to '
#                                 'defect but suggests they will be replaced by '
#                                 'M&S customers who can’t buy its food online '
#                                 'at the moment. Ocado owns the customer data '
#                                 'so “will be able to target those customers '
#                                 'that it views to be most at risk from '
#                                 'switching”, he suggested.\n'
#                                 '\n'
#                                 '“While everyone is looking at the potential '
#                                 'impact from Ocado’s perspective, we believe '
#                                 'investors are failing to acknowledge the '
#                                 'negative impact on Waitrose, from ending the '
#                                 'Ocado contract,” continued Davies who said '
#                                 'the tie-up generated 6% of Waitrose’s sales. '
#                                 '“This will have a material impact on '
#                                 'Waitrose’s owner, the John Lewis Partnership, '
#                                 'which is already struggling with margins that '
#                                 'have fallen.”\n'
#                                 '\n'
#                                 'Topics\n'
#                                 '\n'
#                                 'Waitrose\n'
#                                 '\n'
#                                 'Ocado\n'
#                                 'Retail industry\n'
#                                 'Online shopping\n'
#                                 'Marks & Spencer\n'
#                                 'John Lewis\n'
#                                 'Supermarkets\n'
#                                 'news\n'
#                                 '\n'
#                                 'Share on Facebook\n'
#                                 'Share on Twitter\n'
#                                 'Share via Email\n'
#                                 'Share on LinkedIn\n'
#                                 'Share on Pinterest\n'
#                                 'Share on WhatsApp\n'
#                                 'Share on Messenger\n'
#                                 '\n'
#                                 'Reuse this content',
#                  'associatedMedia': {'properties': {'contentUrl': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=300&quality=85&auto=format&fit=max&s=4c0443760fc652dad651f55c4bfce7cc',
#                                                     'description': 'Analysts '
#                                                                    'suggest '
#                                                                    'the end of '
#                                                                    'the Ocado '
#                                                                    'deal may '
#                                                                    'have badly '
#                                                                    'affect '
#                                                                    'Waitrose’s '
#                                                                    'owner, the '
#                                                                    'John Lewis '
#                                                                    'Partnership. '
#                                                                    'Photograph: '
#                                                                    'Andrew '
#                                                                    'Matthews/PA',
#                                                     'height': '2100',
#                                                     'representativeOfPage': 'true',
#                                                     'url': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=700&quality=85&auto=format&fit=max&s=8c4fdd2153ed244918a8a293c24d4f6e',
#                                                     'width': '3500'},
#                                      'type': 'http://schema.org/ImageObject'},
#                  'author': {'properties': {'name': 'Zoe Wood',
#                                            'sameAs': 'https://www.theguardian.com/profile/zoewood'},
#                             'type': 'http://schema.org/Person'},
#                  'dateModified': ['2020-02-12T13:42:07+0000',
#                                   '2020-02-12T13:42:07+0000'],
#                  'datePublished': '2020-02-10T06:00:27+0000',
#                  'description': 'Supermarket will launch thousands of new and '
#                                 'revamped products aiming to retain online '
#                                 'customers',
#                  'headline': 'Waitrose to launch charm offensive as Ocado '
#                              'switches to M&S',
#                  'image': {'properties': {'contentUrl': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=300&quality=85&auto=format&fit=max&s=4c0443760fc652dad651f55c4bfce7cc',
#                                           'description': 'Analysts suggest the '
#                                                          'end of the Ocado '
#                                                          'deal may have badly '
#                                                          'affect Waitrose’s '
#                                                          'owner, the John '
#                                                          'Lewis Partnership. '
#                                                          'Photograph: Andrew '
#                                                          'Matthews/PA',
#                                           'height': '2100',
#                                           'representativeOfPage': 'true',
#                                           'url': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=700&quality=85&auto=format&fit=max&s=8c4fdd2153ed244918a8a293c24d4f6e',
#                                           'width': '3500'},
#                            'type': 'http://schema.org/ImageObject'},
#                  'mainEntityOfPage': 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms',
#                  'publisher': {'properties': {'logo': {'properties': {'height': '60',
#                                                                       'url': 'https://uploads.guim.co.uk/2018/01/31/TheGuardian_AMP.png',
#                                                                       'width': '190'},
#                                                        'type': 'https://schema.org/ImageObject'},
#                                               'name': 'The Guardian'},
#                                'type': 'https://schema.org/Organization'}},
#   'type': 'http://schema.org/NewsArticle'}]
# **********
# json-ld
# [{'@context': 'http://schema.org',
#   '@type': 'Organization',
#   'logo': {'@type': 'ImageObject',
#            'height': 60,
#            'url': 'https://uploads.guim.co.uk/2018/01/31/TheGuardian_AMP.png',
#            'width': 190},
#   'name': 'The Guardian',
#   'sameAs': ['https://www.facebook.com/theguardian',
#              'https://twitter.com/guardian',
#              'https://www.youtube.com/user/TheGuardian'],
#   'url': 'http://www.theguardian.com/'},
#  {'@context': 'http://schema.org',
#   '@id': 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms',
#   '@type': 'WebPage',
#   'potentialAction': {'@type': 'ViewAction',
#                       'target': 'android-app://com.guardian/https/www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'}}]
# **********
# opengraph
# [{'namespace': {'article': 'http://ogp.me/ns/article#',
#                 'og': 'http://ogp.me/ns#'},
#   'properties': [('og:url',
#                   'http://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'),
#                  ('article:author',
#                   'https://www.theguardian.com/profile/zoewood'),
#                  ('og:image:height', '720'),
#                  ('og:description',
#                   'Supermarket will launch thousands of new and revamped '
#                   'products aiming to retain online customers'),
#                  ('og:image:width', '1200'),
#                  ('og:image',
#                   'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=9719e60266c3af3c231324b6969a0c84'),
#                  ('article:publisher', 'https://www.facebook.com/theguardian'),
#                  ('og:type', 'article'),
#                  ('article:section', 'Business'),
#                  ('article:published_time', '2020-02-10T06:00:27.000Z'),
#                  ('og:title',
#                   'Waitrose to launch charm offensive as Ocado switches to '
#                   'M&S'),
#                  ('article:tag',
#                   'Waitrose,Ocado,Business,UK news,Retail industry,Online '
#                   'shopping,Marks & Spencer,John Lewis,Supermarkets,Money'),
#                  ('og:site_name', 'the Guardian'),
#                  ('article:modified_time', '2020-02-12T13:42:07.000Z')]}]
# **********
# microformat
# []
# **********
# rdfa
# [{'@id': '_:N0551e220fa6d434a80f29c61dc136cc7',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N7fd212118d874186a040f57f765be59c',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N5a6e50ccc1604dbaa5267f2b8ea6ae6b',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N3bc8df2674eb4f80a0b862b46fcb5e72',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N24883650356f449eb3e03e0141e1d1ff',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N66e3ee08e7aa4326ac2ea65e5833864f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#  {'@id': '_:Nc014ddccbc1c470abb38c9b3ffffc6e1',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N207239685f214c6394a5f5f04ac00059',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nbec7754e8fe844f7b68d6d0f743c0dde',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N7bcaf1cead62402698f240dfc819a446',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nef7c3bf2679645fe849bfe9d42f18d1d',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ne3ee1172a905448ebc8a4ad5f2753faf',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nd97131a5c7c6456fbc50690bdddc4bac',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menubar'}]},
#  {'@id': '_:N690e6c4b0e464f76ade5a60b60246d79',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N4ffa55acedff4a0b8af582156694c32b',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nf951dea40196403ba3d4d92751824eb8',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N0c384349403a4bf8b3e83c3b13177f58',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nc64900120c6343b9a2dc11194e3853ea',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Na164cadaa2694ba18428ed0665a6e09f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#  {'@id': '_:Nd6542a4f6adb447180f33b7712001629',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N9d941c95daf04577b00c374b01fce740',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N28c4cc829c244daaab62a70732b84acc',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '',
#   'al:ios:app_name': [{'@value': 'The Guardian'}],
#   'al:ios:app_store_id': [{'@value': '409128287'}],
#   'al:ios:url': [{'@value': 'gnmguardian://business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms?contenttype=Article&source=applinks'}],
#   'article:author': [{'@value': 'https://www.theguardian.com/profile/zoewood'}],
#   'article:modified_time': [{'@value': '2020-02-12T13:42:07.000Z'}],
#   'article:published_time': [{'@value': '2020-02-10T06:00:27.000Z'}],
#   'article:publisher': [{'@value': 'https://www.facebook.com/theguardian'}],
#   'article:section': [{'@value': 'Business'}],
#   'article:tag': [{'@value': 'Waitrose,Ocado,Business,UK news,Retail '
#                              'industry,Online shopping,Marks & Spencer,John '
#                              'Lewis,Supermarkets,Money'}],
#   'http://ogp.me/ns#description': [{'@value': 'Supermarket will launch '
#                                               'thousands of new and revamped '
#                                               'products aiming to retain '
#                                               'online customers'}],
#   'http://ogp.me/ns#image': [{'@value': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=9719e60266c3af3c231324b6969a0c84'}],
#   'http://ogp.me/ns#image:height': [{'@value': '720'}],
#   'http://ogp.me/ns#image:width': [{'@value': '1200'}],
#   'http://ogp.me/ns#site_name': [{'@value': 'the Guardian'}],
#   'http://ogp.me/ns#title': [{'@value': 'Waitrose to launch charm offensive as '
#                                         'Ocado switches to M&S'}],
#   'http://ogp.me/ns#type': [{'@value': 'article'}],
#   'http://ogp.me/ns#url': [{'@value': 'http://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'}],
#   'http://ogp.me/ns/fb#app_id': [{'@value': '180444840287'}],
#   'http://ogp.me/ns/fb#pages': [{'@value': '10513336322'},
#                                 {'@value': '516977308337360'},
#                                 {'@value': '456740217686384'}]},
#  {'@id': '_:Ne34df2ccd31c418cac23c15585132e47',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nac5c396b57394f83803ff288ba8392c1',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N838170fe140641debdb5a9906c137cfb',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N57a3560460054972b35e094239ab16ff',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N76c8257487da4746871707b32e256b79',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N011b57a37b864e298d5e3104de3fd8fc',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N4a62b24ec5f1421bab141297808875ec',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N84fe05a1e2fd4c219f5004bddb064b17',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N079dfd96de2341ca884d0de5bfb8f263',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nb1581a606af24e688da1652230043076',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Na349755d76414044bdadf6c50a59ef75',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Ndd214aca4cb24ab49e17fc1a008f6bc9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N6735bf4dff01493481e68ffed7d46c76',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N1bda30989f2943da8cfd66af0181563a',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nd91d4b6ca3bf419eb40cb80ba6a86ad5',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N0eb49a4e00f24e86b09072f7e6efb1a9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N4d96226c45ca4b789874d8b013d7406e',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#  {'@id': '_:Nc9b7af706c3e4e0d9ae20b9ae3576eb2',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N95e76ac01a7747a5b1157cbca47de933',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N20b0e9050f31448495dac6c8f9b399c5',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N04c972d078dd462ab000e69f6f063e1f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N0142fd59d743438bb6007978b9e1fa97',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#navigation'}]},
#  {'@id': '_:Nb720027c1b4940889e7946a4afaa8b44',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N7647d4e706dd4ea6bc4a5551dea90022',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N5e6c4cb665944aea97c390cef3eb5d43',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nf607986fc4494ed7a29c169205c6e794',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N62e06f3c752445a699102137ec85b221',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#  {'@id': '_:Ne3a087019dd0499890212e27411a5ad5',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N47af20c98f554c399364d8ff9b93ac1f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nc044f4599c6e415db4fe19c2a3b0da60',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '#article',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#main'}]},
#  {'@id': '_:N0b5a4a65a2494f8d9168f10ead71f1a1',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Naca469e0f1fa43ad8ea2871c0c6674ec',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nb50f5bb6f0054780b961aa8e4115c527',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menubar'}]},
#  {'@id': '_:N24086af4d5ad488fa1b8eca06c847e32',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#dialog'}]},
#  {'@id': '_:Nd5df58383c70499f9cdc6c86b1661766',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N0f12d95cecea4e0d94dcc1b7db725454',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nf9c98bb0df84419db5382722a6b3daee',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N790ef304998a4df49e8f82c301afd426',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Ncd385129af654957a14b6241dc0abe88',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N923b08dbfec84406b38af3d20f057b46',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nd98fd3342933471d84a8715ee922d8b2',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N3a82f5fcf1e7460eb36dc8e2e8aee4e2',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N7d3a7ca18cf64b05b68ee4b28ffc0da1',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N2427d247d11f44719479de25a3cac18b',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '#search-popup',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#dialog'}]},
#  {'@id': '_:N853e4c64cb80426baadaaf8ea726c444',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N6dc07ee694f341298a45198fb8eb864c',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N12c76fee993b4ce7943d93085495fb37',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N366d612349954827aa99a5d0e8db1570',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menubar'}]},
#  {'@id': '_:N77642c2768fc4376bc670c6b0b6bb1be',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N20c54b611505414589867b1dadb17587',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N0c7d0c42eec24be7885dee03910d06c3',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N04015990ec054ee18f4b31ffcca3f9b5',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N1e1fc97dac8448c0b76161a8a2a0651a',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nb92410777cb54183bc9c4e964298880f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N5f8113504683459ab2256b9d03a42790',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#banner'}]},
#  {'@id': '_:Ndaddcbec4e2a4994b408350b9f0fa2ba',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ndcef3e457c4141c78fecf1546e1755af',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N35a09cac7c7445c5a18a22116350de0e',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N34d10887bfe04198b52097677a4c91c9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Na0e7dcf5744a4c379cd5444f7704d821',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N7cdbe407f073400c9f55d9a82223d921',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N23eb3d5b008a4267a6e60f8e58026adf',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N002d2dfbdc2b49d1a8b5d19fff030611',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ncc7e95b57067455e826d3f794c4e763a',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ne05652e0ef8a4c15bfbd261b472db94f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nda8bf28f1a0344d0abc53b735a37c164',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nb6ada6c0a4b942ac9c6832e6aa1ed2e9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ndb87f5a88f82472b97022144bd598ad2',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N36f79a0253244f97ade4f457e127f5e7',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nac57e127d9084af392bb8fd3ad8ce18a',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N3f844624e5664b80b14fb3d56dd5aca4',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N1417c4f5820c49e4865786906a3224a9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nfd60cdc81191409c8f4b2ea0d76a0f70',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N13e539acfbd34d1287faaa549cdfb54d',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nb8cfd405cdb84e5ba6362d39dcf64821',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nf7bc431eec0e4f25840814c433e31f29',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Ndabb538c16ec4ef981cbc7539cef8da8',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ncd1952cd55154cec8a103bef740901d9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N2ebf868f1c27421d8322613f8955bef5',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N5454406c20c84438aa9c599f136f8f49',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#contentinfo'}]},
#  {'@id': '_:Nc94a15581c64440dbf0507de8d63784d',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Naa770e7bfb744fbf8401af8020409706',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N3dffc150c4c0413a9bdebf2123fe7a18',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nd8146106be184b94ab5ad43b3b1909ff',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N492264a84e71489abaa0702991b07b4e',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nabd783121b9e4ab282c9302884b8d1b0',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nd0fe5fd7bda9419399bb6927b171cf2f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nc82b116226ea49509df955d168bb2ed5',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N3357d3f800234afca56b0e2d34dff703',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#  {'@id': '_:Na40811f3f24f4e119f1ed50aaf10629f',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nf1c20bcc941945bb9f74cb1f6e70ae15',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nfa8793d4eb7948b9b1bb928207efb7af',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N64dc46cb6d1547ada36be16c13818fb7',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Nf06616b7ebe446dabcc7d1def2767321',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N59f32e7efda341ad90c40514b582f34a',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N851f37eefa614fd6ad3f075a7cd7e1db',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N79b8c2d5b38a4e8c8a0a2787ff18214d',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#  {'@id': '_:N8025d00371db48a8839ae2d0487acb26',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ne67ad61ac5044554a751f6087e390ba6',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N85b6267ccefa4ce0b64e95cf335b3c07',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Nf41bc024f21e4827b1fa1b6fcc9ba333',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N36066569a26a4e14ac2a8582208a600c',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Ne435aab400004945877dd09c00baaff4',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N372c6c4067e44e378239205dfc15ebac',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menu'}]},
#  {'@id': '_:N3b0928fc5e604749a4f70a1927b3a267',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#presentation'}]},
#  {'@id': '_:N557db84558904b7e935409ab6f10a998',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N02226ab3fea446e58bc66a45f85374e6',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N0bd63e739eb94d47afb26aefc4df1dbb',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N316028c43a664a3f8b4be755e84c319a',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:Ne25d038382ba449bbfe07d7884717a84',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N08e5d1d67ea643168aa06e87febf9cdf',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N4ecffc15ae064ad29ace7f2f0742cee2',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:Na1b5513742564172a3eec8ffb9a8a024',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N1040cbcd43c34c35ac170f48fbb15978',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N9e012f8f441b4c6e877ae1b279e30ca3',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N4d29fc7e642f4259b0d90838a68b7c49',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N3e8e285c230044da8622f8ede91f3510',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N432c7428554140febd9c0fe702f7cd8c',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N24902f1735734300b575b755cc0a8512',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N464ecbbba078402ea51eadce265f6ab1',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N2fecee0e1fc445188a663e1b39192db9',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N7025866a11074fef940186d6e10179ea',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N0f9045d893d240bd92291dbbcb3e2d06',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#none'}]},
#  {'@id': '_:N7afd9a1576aa4ad59997068177b8815b',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]},
#  {'@id': '_:N5e7386e07dc34ad4bab4ed44b9e9de41',
#   'http://www.w3.org/1999/xhtml/vocab#role': [{'@id': 'http://www.w3.org/1999/xhtml/vocab#menuitem'}]}]

# %%
# Listing 7-12: Microdata example
import requests

url = 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'
my_headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 ' + ' (KHTML, like Gecko) Chrome/61.0.3163.100Safari/537.36'
}

r = requests.get(url, headers = my_headers)
html_response = r.text

data = extruct.extract(html_response, syntaxes = ['microdata'])
data_keys = data["microdata"][1]["properties"].keys()
for key in data_keys:
    print("*"*10)
    print(key)
    print(data["microdata"][1]["properties"][key])
# Out:
# **********
# mainEntityOfPage
# https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms
# **********
# publisher
# {'type': 'https://schema.org/Organization', 'properties': {'name': 'The Guardian', 'logo': {'type': 'https://schema.org/ImageObject', 'properties': {'url': 'https://uploads.guim.co.uk/2018/01/31/TheGuardian_AMP.png', 'width': '190', 'height': '60'}}}}
# **********
# headline
# Waitrose to launch charm offensive as Ocado switches to M&S
# **********
# description
# Supermarket will launch thousands of new and revamped products aiming to retain online customers
# **********
# author
# {'type': 'http://schema.org/Person', 'properties': {'sameAs': 'https://www.theguardian.com/profile/zoewood', 'name': 'Zoe Wood'}}
# **********
# datePublished
# 2020-02-10T06:00:27+0000
# **********
# dateModified
# ['2020-02-12T13:42:07+0000', '2020-02-12T13:42:07+0000']
# **********
# associatedMedia
# {'type': 'http://schema.org/ImageObject', 'properties': {'representativeOfPage': 'true', 'url': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=700&quality=85&auto=format&fit=max&s=8c4fdd2153ed244918a8a293c24d4f6e', 'width': '3500', 'height': '2100', 'contentUrl': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=300&quality=85&auto=format&fit=max&s=4c0443760fc652dad651f55c4bfce7cc', 'description': 'Analysts suggest the end of the Ocado deal may have badly affect Waitrose’s owner, the John Lewis Partnership. Photograph: Andrew Matthews/PA'}}
# **********
# image
# {'type': 'http://schema.org/ImageObject', 'properties': {'representativeOfPage': 'true', 'url': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=700&quality=85&auto=format&fit=max&s=8c4fdd2153ed244918a8a293c24d4f6e', 'width': '3500', 'height': '2100', 'contentUrl': 'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=300&quality=85&auto=format&fit=max&s=4c0443760fc652dad651f55c4bfce7cc', 'description': 'Analysts suggest the end of the Ocado deal may have badly affect Waitrose’s owner, the John Lewis Partnership. Photograph: Andrew Matthews/PA'}}
# **********
# articleBody
# Waitrose is to launch thousands of new and revamped products in the coming months as the battle for the hearts and minds of Ocado shoppers moves up a gear.
#
# The supermarket’s deal with the online grocer will finish at the end of August, when it will be replaced by Marks & Spencer. The switchover is high risk for all the brands involved: Ocado risks losing loyal Waitrose shoppers while the supermarket, which is part of the John Lewis Partnership, will have to persuade shoppers to use its own website instead.
#
# Last year, Ocado fired the opening salvo stating its product range would be bigger, cheaper and better quality under the M&S deal. The online grocer will stock 6,000 M&S products, compared with the 4,000 it sells as part of its supply deal with Waitrose. The alternatives would be the “same price or lower, and of the same quality or better” than the Waitrose ones, Ocado said.
#
# Waitrose on the other hand says it is working on 5,000 new or reformulated products – a figure that equates to nearly a third of the 17,000 own-label products sold under house brands such as Duchy, Essential Waitrose and No.1. To come up with more distinctive products the retailer has made a multimillion-pound investment in the kitchens at its Bracknell headquarters in Berkshire.
#
# Sign up to the daily Business Today email or follow Guardian Business on Twitter at @BusinessDesk
#
# The supermarket is also running a “you can taste when it’s Waitrose” advertising campaign to underline its foodie credentials. With short ads focused on “hand-rolled white sourdough bread made in London” and “100% Italian” olive oil produced in Umbria, the marketing push aims to claim the high ground as the UK’s “leading quality food retailer” selling products “unrivalled on quality and taste”.
#
# The charm offensive comes ahead of Ocado’s full-year results on Tuesday when an update on the M&S joint venture is anticipated. After nearly a decade as an unloved listed company, Ocado has become a stock market darling after its chief executive, Tim Steiner, sold its grocery-picking expertise to several foreign supermarkets.
#
# Ocado’s shares have risen 40% over the past 12 months with the company worth more than £8bn, primarily thanks to the overseas deals banked by its tech arm Ocado Solutions (M&S paid £750m for 50% of Ocado Retail, the subsidiary that operates robotic warehouses in the UK). The year was not without its setbacks: its hi-tech warehouse in Andover, Hampshire, was destroyed in a fire. Analysts at Bernstein expect pre-tax losses to have widened to £204m on sales of £1.8bn in 2019.
#
# In praise of delivery drivers – those unsung, everyday heroes
#
# Read more
#
# Waitrose had enlisted Today Development Partners, a technology business run by Ocado co-founder Jonathan Faiman, to help grow its online operation without Ocado. However, the deal ended after just four months and it subsequently emerged Faiman, who left the online business in 2009, was being sued by Ocado.
#
# Thomas Davies, a retail analyst at Berenberg bank, expects some Waitrose shoppers to defect but suggests they will be replaced by M&S customers who can’t buy its food online at the moment. Ocado owns the customer data so “will be able to target those customers that it views to be most at risk from switching”, he suggested.
#
# “While everyone is looking at the potential impact from Ocado’s perspective, we believe investors are failing to acknowledge the negative impact on Waitrose, from ending the Ocado contract,” continued Davies who said the tie-up generated 6% of Waitrose’s sales. “This will have a material impact on Waitrose’s owner, the John Lewis Partnership, which is already struggling with margins that have fallen.”
#
# Topics
#
# Waitrose
#
# Ocado
# Retail industry
# Online shopping
# Marks & Spencer
# John Lewis
# Supermarkets
# news
#
# Share on Facebook
# Share on Twitter
# Share via Email
# Share on LinkedIn
# Share on Pinterest
# Share on WhatsApp
# Share on Messenger
#
# Reuse this content

# %%
# Listing 7-13: json-ld example

data = extruct.extract(html_response, syntaxes = ['json-ld'])
print(data)
# Out:
# {'json-ld': [{'@context': 'http://schema.org',
#    '@type': 'Organization',
#    'logo': {'@type': 'ImageObject',
#     'height': 60,
#     'url': 'https://uploads.guim.co.uk/2018/01/31/TheGuardian_AMP.png',
#     'width': 190},
#    'name': 'The Guardian',
#    'sameAs': ['https://www.facebook.com/theguardian',
#     'https://twitter.com/guardian',
#     'https://www.youtube.com/user/TheGuardian'],
#    'url': 'http://www.theguardian.com/'},
#   {'@context': 'http://schema.org',
#    '@id': 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms',
#    '@type': 'WebPage',
#    'potentialAction': {'@type': 'ViewAction',
#     'target': 'android-app://com.guardian/https/www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'}}]}

# %%
# Listing 7-14: opengraph example

data = extruct.extract(html_response, syntaxes = ['opengraph'])
print(data)
# Out:
# {'opengraph': [{'namespace': {'article': 'http://ogp.me/ns/article#',
#     'og': 'http://ogp.me/ns#'},
#    'properties': [('og:url',
#      'http://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'),
#     ('article:author', 'https://www.theguardian.com/profile/zoewood'),
#     ('og:image:height', '720'),
#     ('og:description',
#      'Supermarket will launch thousands of new and revamped products aiming to retain online customers'),
#     ('og:image:width', '1200'),
#     ('og:image',
#      'https://i.guim.co.uk/img/media/65d537a07a3493f18eef074ac0910e6c768d5f2c/0_58_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=9719e60266c3af3c231324b6969a0c84'),
#     ('article:publisher', 'https://www.facebook.com/theguardian'),
#     ('og:type', 'article'),
#     ('article:section', 'Business'),
#     ('article:published_time', '2020-02-10T06:00:27.000Z'),
#     ('og:title',
#      'Waitrose to launch charm offensive as Ocado switches to M&S'),
#     ('article:tag',
#      'Waitrose,Ocado,Business,UK news,Retail industry,Online shopping,Marks & Spencer,John Lewis,Supermarkets,Money'),
#     ('og:site_name', 'the Guardian'),
#     ('article:modified_time', '2020-02-12T13:42:07.000Z')]}]}

# %%
# Listing 7-15: Extracting dates from url
import re
from dateutil.parser import parse as date_parser

def extract_dates(url):
    
    def parse_date_str(date_str):
        if date_str:
            try:
                return_value = date_parser(date_str)
                if pd.isnull(return_value) is True:
                    return 'None'
                else:
                    return return_value
            except (ValueError, OverflowError, AttributeError, TypeError):
               
                return 'None'

    _STRICT_DATE_REGEX_PREFIX = r'(?<=\W)'
    DATE_REGEX = r'([\./\-_]{0,1}(19|20)\d{2})[\./\-_]{0,1}(([0-3]{0,1}[0-9][\./\-_])|(\w{3,5}[\./\-_]))([0-3]{0,1}[0-9][\./\-]{0,1})?'
    STRICT_DATE_REGEX = _STRICT_DATE_REGEX_PREFIX + DATE_REGEX
    
    date_match = re.search(STRICT_DATE_REGEX, url)
    
    if date_match is not None:
        
        return parse_date_str(date_match.group(0))
    else:
        return 'None'
url = 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'

print(extract_dates(url))
# Out:
# 2020-02-10 00:00:00

# %%
#Listing 7-16
import json
from newspaper import Article
import numpy as np
import pandas as pd
import requests


url = 'https://www.theguardian.com/business/2020/feb/10/waitrose-to-launch-charm-offensive-as-ocado-switches-to-ms'

my_headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 ' + ' (KHTML, like Gecko) Chrome/61.0.3163.100Safari/537.36'
}


r = requests.get(url, headers = my_headers)


html_response = r.text

def newspaper_parse(html):

    article = Article('')
    article.set_html(html)
    article.download()
    
    article_title = None
    json_authors = None
    article_text = None
    article_publish_date = None
    
    try:
    
        article.parse()
    
        json_authors = json.dumps(article.authors)
        
        article_title = article.title
        article_text = article.text
        article_publish_date = article.publish_date
        
    except:
        
        pass
    
    return article_title, json_authors, article_text, article_publish_date

article_title, json_authors, article_text, article_publish_date = newspaper_parse(html_response)

# %%
#Listing 7-16

print(article_title)
print("*"*10)
print(article_publish_date)
print("*"*10)
print(json_authors)
print("*"*10)
print(article_text)
# Out:
# Waitrose to launch charm offensive as Ocado switches to M&S
# **********
# 2020-02-10 06:00:27+00:00
# **********
# ["Zoe Wood"]
# **********
# Waitrose is to launch thousands of new and revamped products in the coming months as the battle for the hearts and minds of Ocado shoppers moves up a gear.
#
# The supermarket’s deal with the online grocer will finish at the end of August, when it will be replaced by Marks & Spencer. The switchover is high risk for all the brands involved: Ocado risks losing loyal Waitrose shoppers while the supermarket, which is part of the John Lewis Partnership, will have to persuade shoppers to use its own website instead.
#
# Last year, Ocado fired the opening salvo stating its product range would be bigger, cheaper and better quality under the M&S deal. The online grocer will stock 6,000 M&S products, compared with the 4,000 it sells as part of its supply deal with Waitrose. The alternatives would be the “same price or lower, and of the same quality or better” than the Waitrose ones, Ocado said.
#
# Waitrose on the other hand says it is working on 5,000 new or reformulated products – a figure that equates to nearly a third of the 17,000 own-label products sold under house brands such as Duchy, Essential Waitrose and No.1. To come up with more distinctive products the retailer has made a multimillion-pound investment in the kitchens at its Bracknell headquarters in Berkshire.
#
# Sign up to the daily Business Today email or follow Guardian Business on Twitter at @BusinessDesk
#
# The supermarket is also running a “you can taste when it’s Waitrose” advertising campaign to underline its foodie credentials. With short ads focused on “hand-rolled white sourdough bread made in London” and “100% Italian” olive oil produced in Umbria, the marketing push aims to claim the high ground as the UK’s “leading quality food retailer” selling products “unrivalled on quality and taste”.
#
# The charm offensive comes ahead of Ocado’s full-year results on Tuesday when an update on the M&S joint venture is anticipated. After nearly a decade as an unloved listed company, Ocado has become a stock market darling after its chief executive, Tim Steiner, sold its grocery-picking expertise to several foreign supermarkets.
#
# Ocado’s shares have risen 40% over the past 12 months with the company worth more than £8bn, primarily thanks to the overseas deals banked by its tech arm Ocado Solutions (M&S paid £750m for 50% of Ocado Retail, the subsidiary that operates robotic warehouses in the UK). The year was not without its setbacks: its hi-tech warehouse in Andover, Hampshire, was destroyed in a fire. Analysts at Bernstein expect pre-tax losses to have widened to £204m on sales of £1.8bn in 2019.
#
# In praise of delivery drivers – those unsung, everyday heroes Read more
#
# Waitrose had enlisted Today Development Partners, a technology business run by Ocado co-founder Jonathan Faiman, to help grow its online operation without Ocado. However, the deal ended after just four months and it subsequently emerged Faiman, who left the online business in 2009, was being sued by Ocado.
#
# Thomas Davies, a retail analyst at Berenberg bank, expects some Waitrose shoppers to defect but suggests they will be replaced by M&S customers who can’t buy its food online at the moment. Ocado owns the customer data so “will be able to target those customers that it views to be most at risk from switching”, he suggested.
#
# “While everyone is looking at the potential impact from Ocado’s perspective, we believe investors are failing to acknowledge the negative impact on Waitrose, from ending the Ocado contract,” continued Davies who said the tie-up generated 6% of Waitrose’s sales. “This will have a material impact on Waitrose’s owner, the John Lewis Partnership, which is already struggling with margins that have fallen.”

# %%
# Listing 7-17: scraping from muckrack's sitemap
import numpy as np
import pandas as pd
import requests

url = 'https://muckrack.com/sitemap.xml'
my_headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 ' + ' (KHTML, like Gecko) Chrome/61.0.3163.100Safari/537.36'
}

r = requests.get(url=url, headers = my_headers)

# %%
# Listing 7-17: scraping from muckrack's sitemap (cont.)

sitemaps = soup.find_all('sitemap')
for sitemap in sitemaps:
    print(sitemap.find('loc').get_text())
    try:
        print(sitemap.find('lastmod').get_text())
        print(sitemap.find('changefreq').get_text())
    except:
        pass
# Out:
# https://muckrack.com/sitemaps/sitemap-pages-1.xml
# https://muckrack.com/sitemaps/sitemap-mrdaily-1.xml
# 2020-08-18T12:01:04-04:00
# https://muckrack.com/sitemaps/sitemap-mrdaily-2.xml
# 2016-09-01T17:01:26-04:00
# https://muckrack.com/sitemaps/sitemap-mrdaily-3.xml
# 2014-02-19T10:28:15-05:00
# https://muckrack.com/sitemaps/sitemap-blog-1.xml
# 2020-08-18T06:00:00-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-1.xml
# 2020-08-18T08:57:12-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-2.xml
# 2020-08-18T17:54:52-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-3.xml
# 2020-08-18T20:35:23-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-4.xml
# 2020-08-18T14:29:40-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-5.xml
# 2020-08-18T19:14:41-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-6.xml
# 2020-08-18T08:09:16-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-7.xml
# 2020-08-18T22:29:03-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-8.xml
# 2020-08-18T08:38:07-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-9.xml
# 2020-08-18T15:56:52-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-10.xml
# 2020-08-18T07:58:23-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-11.xml
# 2020-08-18T10:15:02-04:00
# https://muckrack.com/sitemaps/sitemap-media_outlets-12.xml
# 2020-08-18T08:51:48-04:00
# https://muckrack.com/sitemaps/sitemap-beats-1.xml
# 2018-03-28T11:31:54-04:00
# https://muckrack.com/sitemaps/sitemap-person-1.xml
# 2020-08-19T00:05:04-04:00
# https://muckrack.com/sitemaps/sitemap-person-2.xml
# 2020-08-19T00:16:05-04:00
# https://muckrack.com/sitemaps/sitemap-person-3.xml
# 2020-08-19T00:31:39-04:00
# https://muckrack.com/sitemaps/sitemap-person-4.xml
# 2020-08-19T00:00:47-04:00
# https://muckrack.com/sitemaps/sitemap-person-5.xml
# 2020-08-19T00:03:56-04:00
# https://muckrack.com/sitemaps/sitemap-person-6.xml
# 2020-08-18T23:39:24-04:00
# https://muckrack.com/sitemaps/sitemap-person-7.xml
# 2020-08-18T23:58:13-04:00
# https://muckrack.com/sitemaps/sitemap-person-8.xml
# 2020-08-18T22:54:28-04:00
# https://muckrack.com/sitemaps/sitemap-person-9.xml
# 2020-08-18T23:28:30-04:00
# https://muckrack.com/sitemaps/sitemap-person-10.xml
# 2020-08-19T00:27:06-04:00
# https://muckrack.com/sitemaps/sitemap-person-11.xml
# 2020-08-18T21:31:04-04:00
# https://muckrack.com/sitemaps/sitemap-person-12.xml
# 2020-08-19T00:19:49-04:00
# https://muckrack.com/sitemaps/sitemap-person-13.xml
# 2020-08-18T23:58:51-04:00
# https://muckrack.com/sitemaps/sitemap-person-14.xml
# 2020-08-18T23:18:19-04:00
# https://muckrack.com/sitemaps/sitemap-person-15.xml
# 2020-08-18T23:59:39-04:00
# https://muckrack.com/sitemaps/sitemap-person-16.xml
# 2020-08-19T00:36:45-04:00
# https://muckrack.com/sitemaps/sitemap-person-17.xml
# 2020-08-19T00:32:12-04:00
# https://muckrack.com/sitemaps/sitemap-person-18.xml
# 2020-08-18T23:29:28-04:00
# https://muckrack.com/sitemaps/sitemap-person-19.xml
# 2020-08-19T00:37:49-04:00
# https://muckrack.com/sitemaps/sitemap-person-20.xml
# 2020-08-19T00:23:45-04:00
# https://muckrack.com/sitemaps/sitemap-person-21.xml
# 2020-08-18T23:18:23-04:00
# https://muckrack.com/sitemaps/sitemap-person-22.xml
# 2020-08-19T00:03:28-04:00
# https://muckrack.com/sitemaps/sitemap-person-23.xml
# 2020-08-18T23:25:21-04:00
# https://muckrack.com/sitemaps/sitemap-person-24.xml
# 2020-08-18T23:14:15-04:00
# https://muckrack.com/sitemaps/sitemap-person-25.xml
# 2020-08-19T00:38:17-04:00
# https://muckrack.com/sitemaps/sitemap-person-26.xml
# 2020-08-18T23:23:53-04:00
# https://muckrack.com/sitemaps/sitemap-person-27.xml
# 2020-08-19T00:38:21-04:00
# https://muckrack.com/sitemaps/sitemap-person-28.xml
# 2020-08-19T00:06:55-04:00
# https://muckrack.com/sitemaps/sitemap-person-29.xml
# 2020-08-19T00:01:12-04:00
# https://muckrack.com/sitemaps/sitemap-person-30.xml
# 2020-08-18T23:50:10-04:00
# https://muckrack.com/sitemaps/sitemap-person-31.xml
# 2020-08-18T23:08:30-04:00
# https://muckrack.com/sitemaps/sitemap-person-32.xml
# 2020-08-18T23:30:09-04:00
# https://muckrack.com/sitemaps/sitemap-person-33.xml
# 2020-08-19T00:32:49-04:00
# https://muckrack.com/sitemaps/sitemap-person-34.xml
# 2020-08-18T23:11:18-04:00
# https://muckrack.com/sitemaps/sitemap-person-35.xml
# 2020-08-19T00:22:21-04:00
# https://muckrack.com/sitemaps/sitemap-person-36.xml
# 2020-08-19T00:25:10-04:00
# https://muckrack.com/sitemaps/sitemap-person-37.xml
# 2020-08-18T22:36:04-04:00
# https://muckrack.com/sitemaps/sitemap-person-38.xml
# 2020-08-19T00:01:19-04:00
# https://muckrack.com/sitemaps/sitemap-person-39.xml
# 2020-08-19T00:23:21-04:00
# https://muckrack.com/sitemaps/sitemap-person-40.xml
# 2020-08-19T00:02:13-04:00
# https://muckrack.com/sitemaps/sitemap-person-41.xml
# 2020-08-19T00:11:43-04:00
# https://muckrack.com/sitemaps/sitemap-person-42.xml
# 2020-08-18T23:40:09-04:00
# https://muckrack.com/sitemaps/sitemap-person-43.xml
# 2020-08-19T00:32:03-04:00
# https://muckrack.com/sitemaps/sitemap-person-44.xml
# 2020-08-19T00:31:50-04:00
# https://muckrack.com/sitemaps/sitemap-person-45.xml
# 2020-08-19T00:09:51-04:00
# https://muckrack.com/sitemaps/sitemap-person-46.xml
# 2020-08-19T00:17:12-04:00
# https://muckrack.com/sitemaps/sitemap-person-47.xml
# 2020-08-19T00:06:47-04:00
# https://muckrack.com/sitemaps/sitemap-person-48.xml
# 2020-08-18T23:54:11-04:00
# https://muckrack.com/sitemaps/sitemap-person-49.xml
# 2020-08-19T00:19:44-04:00
# https://muckrack.com/sitemaps/sitemap-person-50.xml
# 2020-08-19T00:47:23-04:00
# https://muckrack.com/sitemaps/sitemap-person-51.xml
# 2020-08-18T23:51:38-04:00
# https://muckrack.com/sitemaps/sitemap-person-52.xml
# 2020-08-19T00:27:25-04:00
# https://muckrack.com/sitemaps/sitemap-person-53.xml
# 2020-08-19T00:29:17-04:00
# https://muckrack.com/sitemaps/sitemap-person-54.xml
# 2020-08-19T00:28:27-04:00
# https://muckrack.com/sitemaps/sitemap-person-55.xml
# 2020-08-19T00:17:15-04:00
# https://muckrack.com/sitemaps/sitemap-person-56.xml
# 2020-08-19T00:46:15-04:00
# https://muckrack.com/sitemaps/sitemap-person-57.xml
# 2020-08-18T21:58:50-04:00
# https://muckrack.com/sitemaps/sitemap-person-58.xml
# 2020-08-19T00:51:43-04:00
# https://muckrack.com/sitemaps/sitemap-person-59.xml
# 2020-08-19T00:17:04-04:00
# https://muckrack.com/sitemaps/sitemap-person-60.xml
# 2020-08-18T23:17:10-04:00
# https://muckrack.com/sitemaps/sitemap-person-61.xml
# 2020-08-19T00:53:18-04:00
# https://muckrack.com/sitemaps/sitemap-person-62.xml
# 2020-08-18T23:52:45-04:00
# https://muckrack.com/sitemaps/sitemap-person-63.xml
# 2020-08-18T22:46:30-04:00
# https://muckrack.com/sitemaps/sitemap-person-64.xml
# 2020-08-18T23:55:39-04:00
# https://muckrack.com/sitemaps/sitemap-person-65.xml
# 2020-08-19T00:56:48-04:00
# https://muckrack.com/sitemaps/sitemap-person-66.xml
# 2020-08-19T00:44:04-04:00
# https://muckrack.com/sitemaps/sitemap-person-67.xml
# 2020-08-18T23:20:22-04:00

# %%
# Listing 7-18: loading person and media outlet sitemaps into separate lists
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'xml')
sitemap_other = []
sitemap_media = []
sitemap_persons = []

sitemaps = soup.find_all('loc')
for sitemap in sitemaps:
    sitemap = sitemap.get_text()
    if 'media' in sitemap:
        sitemap_media.append(sitemap)
    elif 'person' in sitemap:
        sitemap_persons.append(sitemap)
    else:
        sitemap_other.append(sitemap)
print(len(sitemap_media))
print(len(sitemap_persons))
# Out:
# 12
# 67

# %%
# Listing  7-19: fetching muckrack profiles url from sitemap list
import time
temp_list = []
for sitemap_media_url in sitemap_media:
    time.sleep(5)
    r = requests.get(url = sitemap_media_url, headers = my_headers)
    soup = BeautifulSoup(r.text, 'xml')
    sitemaps = soup.find_all('url')
    for sitemap in sitemaps:
        
        temp_dict = {}
        temp_dict['url'] = sitemap.find('loc').get_text()
        
        try:
            last_modified = sitemap.find('lastmod').get_text()
           
        except:
            last_modified = ''
           
            
        temp_dict["last_modified"] = last_modified
        temp_list.append(temp_dict)
import pandas as pd
import numpy as np

df = pd.DataFrame(temp_list)
df.head()
df.to_csv("muckrack_media_fetchlist.csv")

# %%
# Listing 7-20: Parsing media profiles from muckrack.com
import json
import random
import time

def parse_muckrack_media(sitemap_df, number_of_pages):
    final_list = []
    random_int_list = []
    
    for i in range(number_of_pages):
        random_int_list.append(random.randint(0, len(df)))
        
        
    while len(random_int_list) != 0:
        url_index = random_int_list.pop()
        url = sitemap_df.url.iloc[url_index]
        time.sleep(5)
        r = requests.get(url = url, headers = my_headers)
        html_source = r.text
        soup = BeautifulSoup(html_source, 'html.parser')

        temp_dict = {}
        temp_dict["muckrack_profile_url"] = url

        try:
            temp_dict["source_name"] = soup.find('h1', {'class': "mr-font-family-2 top-none bottom-xs"}).get_text()
        except:
            temp_dict["source_name"] = ''

        try:
            temp_dict["description"] = soup.find('div', {'class', 'top-xs'}).get_text()
        except:
            temp_dict["description"] = ''

        try:
            temp_dict["media_type"] = soup.find('div',{'class':'mr-font-weight-semibold'}).get_text()
        except:
            temp_dict["media_type"] = ''

        try:
            temp_dict["url"] = soup.find('div', {'class' : 'mr-contact-item-inner '}).get_text()
        except:
            temp_dict["url"] = ''
        try:
            temp_dict["twitter"] = soup.find('a',{'class', 'mr-contact break-word top-xs js-icon-twitter mr-contact-icon-only'})['href']
        except:
            temp_dict["twitter"] = ''
        try:
            temp_dict["linkedin"] = soup.find('a', {'class', 'mr-contact break-word top-xs js-icon-linkedin mr-contact-icon-only'})['href']
        except:
            temp_dict["linkedin"] = ''
        try:
            temp_dict['facebook'] = soup.find('a', {'class', 'mr-contact break-word top-xs js-icon-facebook mr-contact-icon-only'})['href']
        except:
            temp_dict['facebook'] = ''
        try:
            temp_dict['youtube'] = soup.find('a', {'class', 'mr-contact break-word top-xs js-icon-youtube-play mr-contact-icon-only'})['href']
        except:
            temp_dict['youtube'] = ''
        try:
            temp_dict['Pinterest'] = soup.find('a', {'class', 'mr-contact break-word top-xs js-icon-pinterest mr-contact-icon-only'})['href']
        except:
            temp_dict['Pinterest'] = ''
        try:
            temp_dict['Instagram'] = soup.find('a', {'class', 'mr-contact break-word top-xs js-icon-instagram mr-contact-icon-only'})['href']
        except:
            temp_dict['Instagram'] = ''

        for tr in soup.find_all('tr'):
            tds = tr.find_all('td')
            th = tr.find_all('th')
            try:
                temp_dict[th[0].get_text().strip()] = tds[0].get_text().strip()
            except:
                pass
        jr_list = []

        bottom_section = soup.find_all("div", {'class', 'row bottom-sm'})

        rows = soup.find_all('div', {'class', 'mr-directory-item'})
        jr_list = []
        for row in rows:
            if row is not None:
                jr_dict = {}
                jr_dict["name"] = row.get_text().strip()
                jr_dict["profile_url"] = 'https://muckrack.com'+row.find('a')["href"]
                jr_list.append(jr_dict)
        temp_dict["journalists"] = json.dumps(jr_list)
        final_list.append(temp_dict)
    return final_list

# %%
# Listing 7-20: Parsing media profiles from muckrack.com

sample_list = parse_muckrack_media(df, 5)
df_sample.to_csv("muckrack_media.csv", index = False)
df_sample = pd.DataFrame(sample_list)
df_sample.head()
# Out:
#                     Country                                 Days Published  \
# 0            United Kingdom                                            NaN
# 1                     Spain  Mon, \nTue, \nWed, \nThu, \nFri, \nSat, \nSun
# 2                    Mexico                                            NaN
# 3  United States of America                                            NaN
# 4  United States of America                                            Thu
#
#   Frequency                              Instagram Language Pinterest  \
# 0       NaN    https://instagram.com/vivamagazines  English
# 1     Daily                                         Spanish
# 2       NaN    https://instagram.com/must_magazine  Spanish
# 3  Biyearly  https://www.instagram.com/cakeboymag/  English
# 4    Weekly                                         English
#
#                                                Scope UVM\nInsights by  \
# 0                                              Local  Request pricing
# 1                                              Local  Request pricing
# 2                                           National  Request pricing
# 3  International, \n                    \n       ...  Request pricing
# 4                                           Consumer  Request pricing
#
#                                          description  \
# 0  VIVA Magazine is a exciting addition to the wo...
# 1  The news must be told as always, on paper, and...
# 2
# 3  Cakeboy magazine is a bi-annual print publicat...
# 4  We are such big fans of the Fixer Upper TV Sho...
#
#                                             facebook  \
# 0            https://www.facebook.com/vivamagazines/
# 1  https://www.facebook.com/latribunacuenca/?ref=...
# 2             https://www.facebook.com/MustTechStyle
# 3               https://www.facebook.com/CakeboyMag/
# 4  https://www.facebook.com/groups/FixerUpperPodc...
#
#                                          journalists  \
# 0  [{"name": "Bones, Lauren", "profile_url": "htt...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                             linkedin  \
# 0  https://www.linkedin.com/company/viva-lifestyl...
# 1
# 2
# 3
# 4
#
#                                           media_type  \
# 0                                           Magazine
# 1                                          Newspaper
# 2                                           Magazine
# 3  \n                        \n                  ...
# 4  \n                        \n                  ...
#
#                                 muckrack_profile_url              source_name  \
# 0   https://muckrack.com/media-outlet/vivamanchester            Viva Magazine
# 1  https://muckrack.com/media-outlet/latribunadec...     La Tribuna de Cuenca
# 2             https://muckrack.com/media-outlet/must        MUST Tech & Style
# 3       https://muckrack.com/media-outlet/cakeboymag         Cakeboy Magazine
# 4  https://muckrack.com/media-outlet/FixerUpperPo...  The Fixer Upper Podcast
#
#                                twitter                           url  \
# 0    https://twitter.com/vivamagazines  http://vivamanchester.co.uk/
# 1  https://twitter.com/tribunadecuenca   http://latribunadecuenca.es
# 2    https://twitter.com/MUST_MAGAZINE           http://must.com.mx/
# 3       https://twitter.com/cakeboymag         http://cakeboymag.com
# 4    https://twitter.com/FixerUpperPod  http://FixerUpperPodcast.com
#
#                                       youtube
# 0  https://www.youtube.com/user/vivamagazines
# 1
# 2
# 3
# 4

# %%
# Listing 7-21: creating a SQS queue 

import boto3
import json
import sys
import time

def CreateQueue(topic_name):
    
        sqs = boto3.client('sqs',  region_name = 'us-east-1')
        
        millis = str(int(round(time.time() * 1000)))

        
        #create SQS queue
        sqsQueueName=topic_name + millis
        sqs.create_queue(QueueName=sqsQueueName)
        sqsQueueUrl = sqs.get_queue_url(QueueName=sqsQueueName)['QueueUrl']
 
        attribs = sqs.get_queue_attributes(QueueUrl=sqsQueueUrl,
                                                    AttributeNames=['QueueArn'])['Attributes']
                                        
        sqsQueueArn = attribs['QueueArn']
    
        return({"sqsQueueArn":sqsQueueArn,"sqsQueueUrl":sqsQueueUrl})

response_dict = CreateQueue("cc-news-daily")

# %%
response_dict
# Out:
# {'sqsQueueArn': 'arn:aws:sqs:us-east-1:896493407642:cc-news-daily1597659958131',
#  'sqsQueueUrl': 'https://queue.amazonaws.com/896493407642/cc-news-daily1597659958131'}

# %%
# Listing 7-22: fetching json through cc-index api

import urllib

def get_index_url(query_url):

    query = urllib.parse.quote_plus(query_url)
    base_url = 'https://index.commoncrawl.org/CC-MAIN-2020-16-index?url='
    index_url = base_url + query + '&output=json'
    return index_url
query_url = 'theguardian.com/*'
index_url = get_index_url(query_url)

import re
import time
import gzip
import json
import requests
try:
    from io import BytesIO
except:
    from StringIO import StringIO
def get_index_json(index_url):
    pages_list = []
    
    
    for i in range(4):
        resp = requests.get(index_url)
        print(resp.status_code)

        time.sleep(0.2)

        if resp.status_code == 200:
            for x in resp.content.strip().decode().split('\n'):
                page = json.loads(x)
                
                try:
                    if page['status'] == '200':
                        pages_list.append(page)

                except:
                    pass
            
            break
    return pages_list


index_json = get_index_json(index_url)
print(len(index_json))
# Out:
# 200
# 7107

# %%
index_json[:2]
# Out:
# [{'charset': 'UTF-8',
#   'digest': 'QBTLGLXQTDGLQLVM7A4LU3DTRFG3R2VI',
#   'filename': 'crawl-data/CC-MAIN-2020-16/segments/1585370506673.7/warc/CC-MAIN-20200402045741-20200402075741-00316.warc.gz',
#   'languages': 'eng',
#   'length': '76786',
#   'mime': 'text/html',
#   'mime-detected': 'text/html',
#   'offset': '1172149968',
#   'status': '200',
#   'timestamp': '20200402071759',
#   'url': 'https://www.theguardian.com/about',
#   'urlkey': 'com,theguardian)/about'},
#  {'charset': 'UTF-8',
#   'digest': 'NLFT46TQ2MZ6ATH2P7I4YG6PPKAU4YST',
#   'filename': 'crawl-data/CC-MAIN-2020-16/segments/1585371700247.99/warc/CC-MAIN-20200407085717-20200407120217-00485.warc.gz',
#   'languages': 'eng',
#   'length': '105122',
#   'mime': 'text/html',
#   'mime-detected': 'text/html',
#   'offset': '1173563705',
#   'status': '200',
#   'timestamp': '20200407112300',
#   'url': 'https://www.theguardian.com/activate/video-interview-with-rose-shuman-founder-question-box',
#   'urlkey': 'com,theguardian)/activate/video-interview-with-rose-shuman-founder-question-box'}]

# %%
# loading the SQS queue

# %%
# Listing 7-23: loading messages on sqs

response_dict = {'sqsQueueArn': 'arn:aws:sqs:us-east-1:896493407642:cc-news-daily1597659958131',
 'sqsQueueUrl': 'https://queue.amazonaws.com/896493407642/cc-news-daily1597659958131'}

import boto3
import json
from datetime import datetime
def myconverter(o):
    if isinstance(o, datetime):
        return o.__str__()
# Create SQS client
sqs = boto3.client('sqs',region_name = 'us-east-1')

queue_url = response_dict["sqsQueueUrl"]
for line in index_json[:5]:
    payload = json.dumps(line, default = myconverter)
    # Send message to SQS queue
    response = sqs.send_message(
        QueueUrl=queue_url,
        DelaySeconds=10,
        MessageAttributes={

        },
        MessageBody=(
            payload
        )
    )

    print(response['MessageId'])
# Out:
# 654633cc-a901-42a5-a42c-4700ef6091ce
# 9aafeb1b-c3ef-4bd8-982d-601cdf7c6f67
# 33cef889-4622-4b42-b7aa-d7503f558665
# 38a2c47e-b328-4edc-b860-47b898c9b1ef
# 57f5594f-b638-4f4e-a427-179c9d50e948

# %%
# Listing 7-24: Worker node script download and parse from S3 bucket
import json
from newspaper import Article
import numpy as np
import pandas as pd

def newspaper_parse(html):

    article = Article('')
    article.set_html(html)
    article.download()
    
    article_title = None
    json_authors = None
    article_text = None
    article_publish_date = None
    
    try:
    
        article.parse()
    
        json_authors = json.dumps(article.authors)
        
        article_title = article.title
        article_text = article.text
        article_publish_date = article.publish_date
        
    except:
        
        pass
    
    return  article_title, json_authors, article_text, article_publish_date

def get_html_from_cc_index(page):
    
    offset, length = int(page['offset']), int(page['length'])
    offset_end = offset + length - 1
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    temp_list = []

    try:

        resp2 = requests.get(prefix + page['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    
        raw_data = BytesIO(resp2.content)
        f = gzip.GzipFile(fileobj=raw_data)
        data = f.read()
    except:

        print('some error in connection?')

    try:

        temp_dict = {}
        warc, header, response = data.strip().decode().split('\r\n\r\n', 2)
        temp_dict["article_title"], authors_list, temp_dict["article_text"], temp_dict["article_publish_date"] = newspaper_parse(response)
        temp_dict["url"] = page["url"]
        authors_list = json.loads(authors_list)
        if len(authors_list) == 0:
            temp_dict["author"] = ''
            temp_list.append(temp_dict)

        else:
            for author in authors_list:

                temp_dict["author"] = author


    except Exception as e:
        pass
        print(e)
    
    return temp_dict

# %%
# Listing 7-25: Iterating through the SQS queue

import pandas as pd
import numpy as np
import os
import uuid

def upload_to_s3(final_list, S3_bucket_name):
    
    local_filename = str(uuid.uuid4()) + '.csv'
    
    df = pd.DataFrame(final_list)
    df.to_csv(local_filename, index = False)
    
    s3 = boto3.client('s3',region_name = 'us-east-1')
    
    for attempt in range(1,6):
        try:
            # files automatically and upload parts in parallel.
            s3.upload_file(local_filename,S3_bucket_name, local_filename)
            
        except Exception as e:
            print(str(e))
        else:
            print("finished uploading to s3 in attempt ", attempt)
            break
            
    os.remove(local_filename)

final_list = []
while True:

    sqs = boto3.client('sqs',  region_name = 'us-east-1')


    try:
        sqsResponse = sqs.receive_message(QueueUrl=response_dict['sqsQueueUrl'], MessageAttributeNames=['ALL'],
                                                  MaxNumberOfMessages=1, WaitTimeSeconds = 10)


        page = json.loads(sqsResponse["Messages"][0]["Body"])

        receipt_handle = sqsResponse["Messages"][0]["ReceiptHandle"]
        response = sqs.delete_message(QueueUrl=response_dict['sqsQueueUrl'], ReceiptHandle=receipt_handle)

        final_list.append(get_html_from_cc_index(page))
        
        if len(final_list) == 1000:
            upload_to_s3(final_list, 'ec2-testing-for-s3-permissions')
            final_list = []

    except Exception as E:
        print('no more messages to fetch')
        upload_to_s3(final_list, 'ec2-testing-for-s3-permissions')
        break
# Out:
# no more messages to fetch
# finished uploading to s3 in attempt  1

# %%
# Listing 7-26: Parsed content from theguardian.com
df_responses = pd.DataFrame(final_list)
df_responses.head()
# Out:
#        article_publish_date  \
# 0                       NaT
# 1 2010-06-15 09:39:34+00:00
# 2 2011-05-27 09:24:00+00:00
# 3                       NaT
# 4 2010-06-15 09:39:34+00:00
#
#                                         article_text  \
# 0  Katharine Viner is editor-in-chief of the Guar...
# 1  What term do you want to search? Search with g...
# 2  What term do you want to search? Search with g...
# 3  US Climate Alliance, Climate Mayors, We Are St...
# 4  What term do you want to search? Search with g...
#
#                                        article_title author  \
# 0                                 About the Guardian
# 1  Video interview with Rose Shuman, founder, Ope...
# 2             Activate New York: Rose Shuman - video
# 3  Advertiser content hosted by the Guardian: The...
# 4  Video interview with Rose Shuman, founder, Ope...
#
#                                                  url
# 0                  https://www.theguardian.com/about
# 1  https://www.theguardian.com/activate/video-int...
# 2  https://www.theguardian.com/activate/video/act...
# 3  https://www.theguardian.com/advertiser-content...
# 4  https://www.theguardian.com/activate/video-int...

# %%
# Listing 7-27
# save it in a file named multiprocessing_testing_main.py

from multiprocessing import Pool                                                
import multiprocessing       
import os
def run_process(process):                                                             
        os.system('python {}'.format(process))  
if __name__ == '__main__':

    sample_file_path = 'multiprocessing_testing_processes.py'

    #print(sample_file_path)                                                         
    processes = []                                                  
    pool_count = multiprocessing.cpu_count()
    print("cpu pool count is " + " " + str(pool_count))
    for item in range(pool_count):
        processes.append(str(sample_file_path))
    processes = tuple(processes)    
                                         

    #logging.info("pooled processes started")                                                                               
    pool = Pool(pool_count)                                                        
    pool.map(run_process, processes)
    # add code here to shut off EC2
# Out:
# cpu pool count is  8

# %%
# fetching person sitemaps (not shown in text)
import time
temp_list = []
for sitemap_person_url in sitemap_persons:
    time.sleep(5)
    r = requests.get(url = sitemap_person_url, headers = my_headers)
    soup = BeautifulSoup(r.text, 'xml')
    sitemaps = soup.find_all('url')
    for sitemap in sitemaps:
        
        temp_dict = {}
        temp_dict['url'] = sitemap.find('loc').get_text()
        
        try:
            last_modified = sitemap.find('lastmod').get_text()
           
        except:
            last_modified = ''
           
            
        temp_dict["last_modified"] = last_modified
        temp_list.append(temp_dict)

# %%
# fetching person sitemaps (not shown in text)

import pandas as pd
import numpy as np

df = pd.DataFrame(temp_list)
df.head()
# Out:
#   last_modified                                  url
# 0    2020-01-25       https://muckrack.com/__jackguy
# 1    2020-05-08    https://muckrack.com/__jbernstein
# 2    2019-04-18     https://muckrack.com/__jessclark
# 3    2020-08-12      https://muckrack.com/__jevans__
# 4    2020-05-28  https://muckrack.com/__katieoconnor

# %%
# fetching person sitemaps (not shown in text)

len(df)
# Out:
# 231732

# %%
# fetching person sitemaps (not shown in text)

df.to_csv("muckrack_persons_fetchlist.csv")
